# %%
import sys
print(sys.executable)
# Out:
# C:\Users\AYUSH\Downloads\AIEngineer\GenAi\RAG\Project1\.venv\Scripts\python.exe

# %%
import langchain
import chromadb
import sentence_transformers
import pypdf

print("Environment setup successful")
# Out:
# Environment setup successful
